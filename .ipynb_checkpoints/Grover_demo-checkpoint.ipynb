# %%
import numpy as np 
import networkx as nx  
import matplotlib.pyplot as plt
from graph import GraphColoring
from vqe import GraphColorVQE
from grover import GraphColorGrover

# %%
from qiskit.aqua.components.oracles import LogicalExpressionOracle
from qiskit import QuantumRegister, ClassicalRegister
from qiskit import QuantumCircuit
from qiskit.aqua.components.initial_states import Custom
from qiskit.tools.visualization import plot_histogram

# %% [markdown]
# ## Encoding problem in bits

# %%
edges = [[0,1],[0,2],[0,3],[2,3]]
g = GraphColoring(ncolors=3, edges=edges, nnodes=4) 
g.render_graph('001010100010')
# Out:
# Graph coloring satisfied!

# %% [markdown]
# ![Screen%20Shot%202019-05-08%20at%207.55.58%20AM.png](attachment:Screen%20Shot%202019-05-08%20at%207.55.58%20AM.png)

# %% [markdown]
# ### Oracle Composition

# %% [markdown]
# #### 1. Convert graph coloring problem into a set of constraints

# %%
edges = [[0,1],[0,2],[0,3],[2,3]]
g = GraphColoring(ncolors=3, edges=edges, nnodes=4) 
g.render_graph()

# %% [markdown]
# Constraints to select exactly one color for each node:
#
# $  X_{00} \oplus X_{01} \oplus X_{02} \\
#    X_{10} \oplus X_{11} \oplus X_{12} \\
#    \rightarrow X_{20} \oplus X_{21} \oplus X_{22} \\
#    X_{30} \oplus X_{31} \oplus X_{32} \\
# $

# %% [markdown]
# ![Screen%20Shot%202019-05-08%20at%2010.54.25%20AM.png](attachment:Screen%20Shot%202019-05-08%20at%2010.54.25%20AM.png)

# %% [markdown]
# Constraints to make sure linked nodes have different colors:
#
# $
# \lnot (X_{00} \land X_{10})\\
# \lnot (X_{01} \land X_{11})\\
# \rightarrow \lnot (X_{02} \land X_{12})\\
# \lnot (X_{00} \land X_{20})\\
# \lnot (X_{01} \land X_{21})\\
# \lnot (X_{02} \land X_{22})\\
# \lnot (X_{00} \land X_{30})\\
# \lnot (X_{01} \land X_{31})\\
# \lnot (X_{02} \land X_{32})\\
# $

# %% [markdown]
# ![Screen%20Shot%202019-05-08%20at%2010.56.12%20AM.png](attachment:Screen%20Shot%202019-05-08%20at%2010.56.12%20AM.png)

# %% [markdown]
# #### 2. Use Toffoli Gate to implement boolean constraints

# %%
"""To implement q1 AND q2 simply apply Toffoli"""

q = QuantumRegister(3) 
qc = QuantumCircuit(q)

qc.ccx(q[0],q[1],q[2])
qc.draw(output='mpl')

# %%
"""To implement q1 OR q2 convert expression to NOT( NOT(A) AND NOT(B)) and use Toffoli for the AND"""
q = QuantumRegister(3) 
qc = QuantumCircuit(q)

qc.x(q[0])
qc.x(q[1])
qc.x(q[2])
qc.ccx(q[0],q[1],q[2])
qc.x(q[0])
qc.x(q[1])

qc.draw(output='mpl')

# %% [markdown]
# ### Example

# %%
edges = [[1,0]]
g = GraphColoring(ncolors=2, edges=edges, nnodes=2) 
g.render_graph()

groverGC = GraphColorGrover(g)
constraints = groverGC.graphcover_constraints()
CNF = groverGC.dimacs_format(constraints, groverGC.gc.nnodes*groverGC.gc.ncolors)
print(CNF)
# Out:
# p cnf 4 6
# -2 -1 0
# 1 2 0
# -4 -3 0
# 3 4 0
# -3 -1 0
# -4 -2 0

# %%
q = QuantumRegister(4, 'q') 
c = QuantumRegister(6, 'v') 
a = QuantumRegister(4, 'n') 
o = QuantumRegister(1, 'o') 
qc = QuantumCircuit(q, c, a, o)

qc.x(c[0])
qc.ccx(q[0],q[1],c[0])

qc.x(c[1])
qc.ccx(q[2],q[3],c[1])

qc.x(c[2])
qc.x(q[0])
qc.x(q[1])
qc.ccx(q[0],q[1],c[2])
qc.x(q[0])
qc.x(q[1])

qc.x(c[3])
qc.x(q[2])
qc.x(q[3]) 
qc.ccx(q[2],q[3],c[3])
qc.x(q[2])
qc.x(q[3])

qc.x(c[4])
qc.x(c[5])

qc.barrier()

qc.ccx(q[0],q[2],c[4])
qc.ccx(q[1],q[3],c[5])

qc.barrier() 

qc.ccx(c[0],c[1],a[0])
qc.ccx(c[2],a[0],a[1])
qc.ccx(c[3],a[1],a[2])
qc.ccx(c[4],a[2],a[3])
qc.ccx(c[5],a[3],o[0])

qc.draw(output='mpl', scale=.5)

# %% [markdown]
# ### Grover on quantum simulation

# %%
edges = [[1,0],[1,2],[1,3]]
g = GraphColoring(ncolors=2, edges=edges, nnodes=4) 
g.render_graph()

groverGC = GraphColorGrover(g, 200)
solution = groverGC.run_sim()

plot_histogram(groverGC.result['measurement'])
g.render_graph(solution)
# Out:
# Oracle with number of qubits: 17
# Graph coloring satisfied!

# %%
edges = [[1,0],[1,2],[1,3],[2,3]]
g = GraphColoring(ncolors=3, edges=edges, nnodes=4) 
g.render_graph()

groverGC = GraphColorGrover(g, 200)
solution = groverGC.run_sim()

plot_histogram(groverGC.result['measurement'])
g.render_graph(solution)

# %%
edges = [[2, 1], [3, 1], [4, 1], [5, 0], [5, 3], [6, 0], [6, 5]]
g = GraphColoring(ncolors=3, edges=edges, nnodes=7)
g.render_graph()

groverGC = GraphColorGrover(g, 500)
solution = groverGC.run_sim()

plot_histogram(groverGC.result['measurement'])
g.render_graph(solution)
