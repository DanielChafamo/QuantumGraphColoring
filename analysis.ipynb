# %%
import numpy as np 
import networkx as nx  
import matplotlib.pyplot as plt
from graph import GraphColoring
from vqe import GraphColorVQE
from grover import GraphColorGrover

# %% [markdown]
# ### Grover

# %%
edges = [[1,0],[1,2],[1,3]]
g = GraphColoring(ncolors=2, edges=edges, nnodes=4) 
g.render_graph()

groverGC = GraphColorGrover(g)
solution = groverGC.run()

g.render_graph(solution)

groverGC.visualize(groverGC.result)

# %% [markdown]
# ### VQE

# %%
edges = [[2, 1], [3, 1], [4, 1], [5, 0], [5, 3], [6, 0], [6, 5]]
g = GraphColoring(ncolors=3, edges=edges, nnodes=7)
g.render_graph()

vqeGC = GraphColorVQE(g) 
solution = vqeGC.run(exact=True)

g.render_graph(solution)

# %%
solution = vqeGC.run(exact=False)
g.render_graph(solution)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-26b8beffe9e6> in <module>
# ----> 1 solution = vqeGC.run(exact=False)
#       2 g.render_graph(solution)
#
# ~/Downloads/ES170/QGC/QuantumGraphColoring/vqe.py in run(self, exact)
#      23       self.result = exact_eigensolver.run()
#      24     else:
# ---> 25       self.result = self.vqe(Operator, self.niter, Hamiltonian.shape[0])
#      26
#      27     solution = self.extract_solution(self.result, exact)
#
# ~/Downloads/ES170/QGC/QuantumGraphColoring/vqe.py in vqe(Operator, niter, nqubits)
#      91     quantum_instance = QuantumInstance(backend=backend)
#      92     vqe = VQE(Operator, var_form, opt)
# ---> 93     return vqe.run(quantum_instance)
#      94
#      95   @staticmethod
#
# ...
